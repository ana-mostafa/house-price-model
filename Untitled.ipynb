# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("London.csv")

# %%
data.head(100)
# Out:
#     Unnamed: 0       Property Name    Price        House Type  Area in sq ft  \
# 0            0         Queens Road  1675000             House           2716
# 1            1       Seward Street   650000  Flat / Apartment            814
# 2            2         Hotham Road   735000  Flat / Apartment            761
# 3            3        Festing Road  1765000             House           1986
# 4            4        Spencer Walk   675000  Flat / Apartment            700
# ..         ...                 ...      ...               ...            ...
# 95          95     Baronsmead Road  4000000             House           3714
# 96          96      Sisters Avenue   500000  Flat / Apartment            516
# 97          97  Warrington Gardens  1275000  Flat / Apartment           1185
# 98          98     Pembroke Villas  4500000             House           2972
# 99          99      North End Road  1750000             House           2125
#
# ...

# %%
data = data.drop(data.columns[0], axis=1)
data.head()
# Out:
#      Price        House Type  Area in sq ft  No. of Bedrooms  \
# 0  1675000             House           2716                5
# 1   650000  Flat / Apartment            814                2
# 2   735000  Flat / Apartment            761                2
# 3  1765000             House           1986                4
# 4   675000  Flat / Apartment            700                2
#
#    No. of Bathrooms  No. of Receptions     Location City/County Postal Code
# 0                 5                  5    Wimbledon      London    SW19 8NY
# 1                 2                  2  Clerkenwell      London    EC1V 3PA
# 2                 2                  2       Putney      London    SW15 1QL
# 3                 4                  4       Putney      London    SW15 1LP
# 4                 2                  2       Putney      London    SW15 1PL

# %%
mode_value = data['Location'].mode()[0]
data['Location'].fillna(mode_value, inplace=True)

# %%
data.head(20)
# Out:
#        Price  House Type  Area in sq ft  No. of Bedrooms  No. of Bathrooms  \
# 0    1675000           3           2716                5                 5
# 1     650000           2            814                2                 2
# 2     735000           2            761                2                 2
# 3    1765000           3           1986                4                 4
# 4     675000           2            700                2                 2
# 5     420000           2            403                1                 1
# 6    1475000           3           1548                4                 4
# 7     650000           5            560                1                 1
# 8    2500000           3           1308                3                 3
# 9     925000           2            646                2                 2
# 10   2400000           3           3392                6                 6
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the "Location" column
data['Location'] = label_encoder.fit_transform(data['Location'])
data['City/County'] = label_encoder.fit_transform(data['City/County'])
data['House Type'] = label_encoder.fit_transform(data['House Type'])
data.head()
# Out:
#      Price  House Type  Area in sq ft  No. of Bedrooms  No. of Bathrooms  \
# 0  1675000           3           2716                5                 5
# 1   650000           2            814                2                 2
# 2   735000           2            761                2                 2
# 3  1765000           3           1986                4                 4
# 4   675000           2            700                2                 2
#
#    No. of Receptions  Location  City/County Postal Code
# 0                  5       650           33    SW19 8NY
# 1                  2       384           33    EC1V 3PA
# 2                  2       558           33    SW15 1QL
# 3                  4       558           33    SW15 1LP
# 4                  2       558           33    SW15 1PL

# %%
# Calculate the mean price for each unique area (postcode)
area_prices = data.groupby('Postal Code')['Price'].mean()

# Map the mean prices to the corresponding postcodes
data['Area Price'] = data['Postal Code'].map(area_prices)

# Drop the original 'Postal Code' column if necessary
data.drop('Postal Code', axis=1, inplace=True)

# %%
data.head()
# Out:
#      Price  House Type  Area in sq ft  No. of Bedrooms  No. of Bathrooms  \
# 0  1675000           3           2716                5                 5
# 1   650000           2            814                2                 2
# 2   735000           2            761                2                 2
# 3  1765000           3           1986                4                 4
# 4   675000           2            700                2                 2
#
#    No. of Receptions  Location  City/County  Area Price
# 0                  5       650           33   1675000.0
# 1                  2       384           33    670000.0
# 2                  2       558           33    735000.0
# 3                  4       558           33   1765000.0
# 4                  2       558           33    675000.0

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['Price'], axis = 1)
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
corr_matrix = data.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Create the scatter plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as per your preference
plt.scatter(area, price, alpha=0.5)  # Adjust alpha for transparency

# Set labels and title
plt.xlabel('Area in sq ft')
plt.ylabel('Price')
plt.title('Scatter Plot of Price vs Area')

# Show the plot
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.9461333674846344

# %%
#random forest regressor
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8853071457085314

# %%
from sklearn.model_selection import GridSearchCV

forestgrid = RandomForestRegressor()

paramgrid = {
    'n_estimators': [5,10,20,30],
    'max_features': [2,4,6],
    'max_depth': [None,5,10]
}

grid_search = GridSearchCV(forestgrid, paramgrid, scoring='neg_mean_squared_error', cv=5)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 5, 10], 'max_features': [2, 4, 6],
#                          'n_estimators': [5, 10, 20, 30]},
#              scoring='neg_mean_squared_error')

# %%
best_model = grid_search.best_estimator_

# %%
best_model.score(X_test, y_test)
# Out:
# 0.904443533709212

# %%
# Out:
# -551516909596.9448
